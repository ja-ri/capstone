# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pygame
import sys
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Initialize Pygame
pygame.init()

# Set the width and height of the screen (adjust as needed)
SCREEN_WIDTH = 1280
SCREEN_HEIGHT = 768

# Set up the screen
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("Drawing with Pygame")

# Set colors
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Set circle parameters
circle_radius = 10  # Adjust as needed

# Open camera
cap = cv2.VideoCapture(2)  # Use 0 for the default camera, change if you have multiple cameras

while(cap.isOpened()):
    ret, frame = cap.read()
    if not ret:
        break

    # Flip the frame vertically
    frame = cv2.flip(frame, 0)

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Thresholding to isolate bright areas (IR light)
    _, thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)

    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through contours
    for contour in contours:
        # Compute centroid of contour
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])

            # Draw centroid on the frame
            cv2.circle(frame, (cX, cY), 5, (0, 0, 255), -1)
            # Print normalized coordinates
            video_height, video_width, _ = frame.shape
            normalized_cX = cX / video_width
            normalized_cY = cY / video_height
            print("Normalized coordinates (x, y):", int(cX * SCREEN_WIDTH / frame.shape[1]), int(cY * SCREEN_HEIGHT / frame.shape[0]))

            # Draw circle at the centroid in Pygame
            pygame.draw.circle(screen, RED, (int(cX * SCREEN_WIDTH / frame.shape[1]), int(cY * SCREEN_HEIGHT / frame.shape[0])), circle_radius)


    # Update the display
    pygame.display.flip()

    for event in pygame.event.get():
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_q:
                cap.release()
                cv2.destroyAllWindows()
                pygame.quit()
                sys.exit()
            elif event.key == pygame.K_c:
                screen.fill(WHITE)
# Out:
# Normalized coordinates (x, y): 652 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 648 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 652 320
# Normalized coordinates (x, y): 652 321
# Normalized coordinates (x, y): 652 321
# Normalized coordinates (x, y): 654 321
# Normalized coordinates (x, y): 654 321
# Normalized coordinates (x, y): 654 323
# Normalized coordinates (x, y): 656 323
# Normalized coordinates (x, y): 656 323
# Normalized coordinates (x, y): 656 323
# Normalized coordinates (x, y): 658 321
# Normalized coordinates (x, y): 660 323
# Normalized coordinates (x, y): 660 321
# Normalized coordinates (x, y): 660 321
# Normalized coordinates (x, y): 662 321
# Normalized coordinates (x, y): 664 321
# Normalized coordinates (x, y): 666 320
# Normalized coordinates (x, y): 666 320
# Normalized coordinates (x, y): 668 320
# Normalized coordinates (x, y): 670 318
# Normalized coordinates (x, y): 672 318
# Normalized coordinates (x, y): 674 316
# Normalized coordinates (x, y): 674 316
# Normalized coordinates (x, y): 676 315
# Normalized coordinates (x, y): 678 313
# Normalized coordinates (x, y): 680 313
# Normalized coordinates (x, y): 682 312
# Normalized coordinates (x, y): 682 310
# Normalized coordinates (x, y): 684 308
# Normalized coordinates (x, y): 686 307
# Normalized coordinates (x, y): 688 307
# Normalized coordinates (x, y): 690 305
# Normalized coordinates (x, y): 692 304
# Normalized coordinates (x, y): 694 302
# Normalized coordinates (x, y): 696 300
# Normalized coordinates (x, y): 696 299
# Normalized coordinates (x, y): 698 297
# Normalized coordinates (x, y): 700 296
# Normalized coordinates (x, y): 702 294
# Normalized coordinates (x, y): 704 292
# Normalized coordinates (x, y): 706 291
# Normalized coordinates (x, y): 708 289
# Normalized coordinates (x, y): 710 289
# Normalized coordinates (x, y): 712 288
# Normalized coordinates (x, y): 714 286
# Normalized coordinates (x, y): 716 284
# Normalized coordinates (x, y): 718 283
# Normalized coordinates (x, y): 722 281
# Normalized coordinates (x, y): 724 281
# Normalized coordinates (x, y): 726 280
# Normalized coordinates (x, y): 728 278
# Normalized coordinates (x, y): 730 278
# Normalized coordinates (x, y): 732 276
# Normalized coordinates (x, y): 734 275
# Normalized coordinates (x, y): 738 275
# Normalized coordinates (x, y): 740 273
# Normalized coordinates (x, y): 742 272
# Normalized coordinates (x, y): 746 272
# Normalized coordinates (x, y): 748 270
# Normalized coordinates (x, y): 750 270
# Normalized coordinates (x, y): 754 268
# Normalized coordinates (x, y): 756 268
# Normalized coordinates (x, y): 758 268
# Normalized coordinates (x, y): 762 268
# Normalized coordinates (x, y): 764 267
# Normalized coordinates (x, y): 766 267
# Normalized coordinates (x, y): 770 267
# Normalized coordinates (x, y): 772 267
# Normalized coordinates (x, y): 774 267
# Normalized coordinates (x, y): 778 267
# Normalized coordinates (x, y): 780 267
# Normalized coordinates (x, y): 782 267
# Normalized coordinates (x, y): 784 267
# Normalized coordinates (x, y): 788 267
# Normalized coordinates (x, y): 790 267
# Normalized coordinates (x, y): 792 268
# Normalized coordinates (x, y): 796 268
# Normalized coordinates (x, y): 798 268
# Normalized coordinates (x, y): 800 268
# Normalized coordinates (x, y): 802 270
# Normalized coordinates (x, y): 804 270
# Normalized coordinates (x, y): 804 272
# Normalized coordinates (x, y): 808 273
# Normalized coordinates (x, y): 808 275
# Normalized coordinates (x, y): 810 276
# Normalized coordinates (x, y): 812 278
# Normalized coordinates (x, y): 814 280
# Normalized coordinates (x, y): 814 281
# Normalized coordinates (x, y): 816 283
# Normalized coordinates (x, y): 818 284
# Normalized coordinates (x, y): 820 286
# Normalized coordinates (x, y): 820 288
# Normalized coordinates (x, y): 822 289
# Normalized coordinates (x, y): 822 291
# Normalized coordinates (x, y): 826 296
# Normalized coordinates (x, y): 830 302
# Normalized coordinates (x, y): 834 312
# Normalized coordinates (x, y): 834 313
# Normalized coordinates (x, y): 834 321
# Normalized coordinates (x, y): 834 324
# Normalized coordinates (x, y): 834 329
# Normalized coordinates (x, y): 834 337
# Normalized coordinates (x, y): 834 340
# Normalized coordinates (x, y): 832 344
# Normalized coordinates (x, y): 832 347
# Normalized coordinates (x, y): 830 350
# Normalized coordinates (x, y): 830 353
# Normalized coordinates (x, y): 828 356
# Normalized coordinates (x, y): 828 358
# Normalized coordinates (x, y): 826 361
# Normalized coordinates (x, y): 826 366
# Normalized coordinates (x, y): 824 368
# Normalized coordinates (x, y): 822 372
# Normalized coordinates (x, y): 820 377
# Normalized coordinates (x, y): 818 382
# Normalized coordinates (x, y): 818 385
# Normalized coordinates (x, y): 818 387
# Normalized coordinates (x, y): 814 390
# Normalized coordinates (x, y): 812 393
# Normalized coordinates (x, y): 812 395
# Normalized coordinates (x, y): 810 398
# Normalized coordinates (x, y): 806 401
# Normalized coordinates (x, y): 806 403
# Normalized coordinates (x, y): 804 406
# Normalized coordinates (x, y): 802 409
# Normalized coordinates (x, y): 800 411
# Normalized coordinates (x, y): 798 412
# Normalized coordinates (x, y): 796 414
# Normalized coordinates (x, y): 794 416
# Normalized coordinates (x, y): 792 417
# Normalized coordinates (x, y): 790 419
# Normalized coordinates (x, y): 788 420
# Normalized coordinates (x, y): 786 422
# Normalized coordinates (x, y): 784 424
# Normalized coordinates (x, y): 782 424
# Normalized coordinates (x, y): 782 425
# Normalized coordinates (x, y): 780 425
# Normalized coordinates (x, y): 780 425
# Normalized coordinates (x, y): 778 427
# Normalized coordinates (x, y): 778 427
# Normalized coordinates (x, y): 778 428
# Normalized coordinates (x, y): 778 428
# Normalized coordinates (x, y): 770 433
# Normalized coordinates (x, y): 768 435
# Normalized coordinates (x, y): 766 435
# Normalized coordinates (x, y): 766 435
# Normalized coordinates (x, y): 764 435
# Normalized coordinates (x, y): 764 436
# Normalized coordinates (x, y): 762 436
# Normalized coordinates (x, y): 762 435
# Normalized coordinates (x, y): 762 436
# Normalized coordinates (x, y): 760 436
# Normalized coordinates (x, y): 758 436
# Normalized coordinates (x, y): 756 438
# Normalized coordinates (x, y): 756 438
# Normalized coordinates (x, y): 754 436
# Normalized coordinates (x, y): 752 436
# Normalized coordinates (x, y): 750 436
# Normalized coordinates (x, y): 748 438
# Normalized coordinates (x, y): 746 438
# Normalized coordinates (x, y): 746 438
# Normalized coordinates (x, y): 744 438
# Normalized coordinates (x, y): 742 438
# Normalized coordinates (x, y): 738 438
# Normalized coordinates (x, y): 736 436
# Normalized coordinates (x, y): 734 436
# Normalized coordinates (x, y): 732 436
# Normalized coordinates (x, y): 730 436
# Normalized coordinates (x, y): 730 436
# Normalized coordinates (x, y): 726 436
# Normalized coordinates (x, y): 726 435
# Normalized coordinates (x, y): 722 435
# Normalized coordinates (x, y): 720 435
# Normalized coordinates (x, y): 718 435
# Normalized coordinates (x, y): 716 435
# Normalized coordinates (x, y): 714 433
# Normalized coordinates (x, y): 712 433
# Normalized coordinates (x, y): 710 433
# Normalized coordinates (x, y): 708 432
# Normalized coordinates (x, y): 706 432
# Normalized coordinates (x, y): 704 432
# Normalized coordinates (x, y): 702 430
# Normalized coordinates (x, y): 700 430
# Normalized coordinates (x, y): 698 430
# Normalized coordinates (x, y): 696 430
# Normalized coordinates (x, y): 698 430
# Normalized coordinates (x, y): 696 430
# Normalized coordinates (x, y): 698 432
# Normalized coordinates (x, y): 694 430
# Normalized coordinates (x, y): 694 432
# Normalized coordinates (x, y): 694 433
# Normalized coordinates (x, y): 694 433
# Normalized coordinates (x, y): 696 436
# Normalized coordinates (x, y): 698 438
# Normalized coordinates (x, y): 698 441
# Normalized coordinates (x, y): 700 443
# Normalized coordinates (x, y): 702 446
# Normalized coordinates (x, y): 704 448
# Normalized coordinates (x, y): 704 449
# Normalized coordinates (x, y): 706 454
# Normalized coordinates (x, y): 708 456
# Normalized coordinates (x, y): 708 457
# Normalized coordinates (x, y): 710 460
# Normalized coordinates (x, y): 710 462
# Normalized coordinates (x, y): 712 464
# Normalized coordinates (x, y): 714 467
# Normalized coordinates (x, y): 714 468
# Normalized coordinates (x, y): 714 470
# Normalized coordinates (x, y): 714 472
# Normalized coordinates (x, y): 716 473
# Normalized coordinates (x, y): 716 475
# Normalized coordinates (x, y): 716 476
# Normalized coordinates (x, y): 716 478
# Normalized coordinates (x, y): 716 480
# Normalized coordinates (x, y): 638 292
# Normalized coordinates (x, y): 638 289
# Normalized coordinates (x, y): 640 288
# Normalized coordinates (x, y): 642 283
# Normalized coordinates (x, y): 644 281
# Normalized coordinates (x, y): 646 280
# Normalized coordinates (x, y): 648 276
# Normalized coordinates (x, y): 650 275
# Normalized coordinates (x, y): 652 272
# Normalized coordinates (x, y): 652 270
# Normalized coordinates (x, y): 654 268
# Normalized coordinates (x, y): 656 267
# Normalized coordinates (x, y): 658 265
# Normalized coordinates (x, y): 660 264
# Normalized coordinates (x, y): 662 262
# Normalized coordinates (x, y): 662 260
# Normalized coordinates (x, y): 666 257
# Normalized coordinates (x, y): 666 256
# Normalized coordinates (x, y): 668 256
# Normalized coordinates (x, y): 670 254
# Normalized coordinates (x, y): 672 252
# Normalized coordinates (x, y): 674 251
# Normalized coordinates (x, y): 676 249
# Normalized coordinates (x, y): 678 246
# Normalized coordinates (x, y): 680 246
# Normalized coordinates (x, y): 682 243
# Normalized coordinates (x, y): 684 241
# Normalized coordinates (x, y): 686 240
# Normalized coordinates (x, y): 688 238
# Normalized coordinates (x, y): 690 236
# Normalized coordinates (x, y): 692 235
# Normalized coordinates (x, y): 694 232
# Normalized coordinates (x, y): 696 230
# Normalized coordinates (x, y): 698 228
# Normalized coordinates (x, y): 700 227
# Normalized coordinates (x, y): 702 225
# Normalized coordinates (x, y): 704 224
# Normalized coordinates (x, y): 706 222
# Normalized coordinates (x, y): 708 220
# Normalized coordinates (x, y): 710 219
# Normalized coordinates (x, y): 714 217
# Normalized coordinates (x, y): 714 216
# Normalized coordinates (x, y): 718 214
# Normalized coordinates (x, y): 720 212
# Normalized coordinates (x, y): 722 212
# Normalized coordinates (x, y): 722 211
# Normalized coordinates (x, y): 724 211
# Normalized coordinates (x, y): 726 211
# Normalized coordinates (x, y): 728 211
# Normalized coordinates (x, y): 730 211
# Normalized coordinates (x, y): 730 211
# Normalized coordinates (x, y): 730 211
# Normalized coordinates (x, y): 730 211
# Normalized coordinates (x, y): 730 211
# Normalized coordinates (x, y): 730 212
# Normalized coordinates (x, y): 730 212
# Normalized coordinates (x, y): 730 214
# Normalized coordinates (x, y): 728 216
# Normalized coordinates (x, y): 726 216
# Normalized coordinates (x, y): 726 217
# Normalized coordinates (x, y): 724 219
# Normalized coordinates (x, y): 722 220
# Normalized coordinates (x, y): 720 222
# Normalized coordinates (x, y): 716 225
# Normalized coordinates (x, y): 714 227
# Normalized coordinates (x, y): 710 228
# Normalized coordinates (x, y): 708 232
# Normalized coordinates (x, y): 704 233
# Normalized coordinates (x, y): 702 235
# Normalized coordinates (x, y): 698 236
# Normalized coordinates (x, y): 696 240
# Normalized coordinates (x, y): 692 241
# Normalized coordinates (x, y): 690 243
# Normalized coordinates (x, y): 688 244
# Normalized coordinates (x, y): 684 246
# Normalized coordinates (x, y): 682 246
# Normalized coordinates (x, y): 680 248
# Normalized coordinates (x, y): 678 248
# Normalized coordinates (x, y): 676 249
# Normalized coordinates (x, y): 674 249
# Normalized coordinates (x, y): 672 249
# Normalized coordinates (x, y): 670 249
# Normalized coordinates (x, y): 670 249
# Normalized coordinates (x, y): 668 249
# Normalized coordinates (x, y): 668 249
# Normalized coordinates (x, y): 668 248
# Normalized coordinates (x, y): 666 248
# Normalized coordinates (x, y): 666 246
# Normalized coordinates (x, y): 666 244
# Normalized coordinates (x, y): 666 243
# Normalized coordinates (x, y): 666 241
# Normalized coordinates (x, y): 668 240
# Normalized coordinates (x, y): 668 238
# Normalized coordinates (x, y): 670 236
# Normalized coordinates (x, y): 670 235
# Normalized coordinates (x, y): 676 228
# Normalized coordinates (x, y): 678 225
# Normalized coordinates (x, y): 682 222
# Normalized coordinates (x, y): 684 220
# Normalized coordinates (x, y): 686 219
# Normalized coordinates (x, y): 690 217
# Normalized coordinates (x, y): 692 216
# Normalized coordinates (x, y): 696 214
# Normalized coordinates (x, y): 696 212
# Normalized coordinates (x, y): 698 212
# Normalized coordinates (x, y): 700 211
# Normalized coordinates (x, y): 702 209
# Normalized coordinates (x, y): 704 209
# Normalized coordinates (x, y): 706 208
# Normalized coordinates (x, y): 706 208
# Normalized coordinates (x, y): 708 206
# Normalized coordinates (x, y): 708 206
# Normalized coordinates (x, y): 708 206
# Normalized coordinates (x, y): 710 206
# Normalized coordinates (x, y): 710 206
# Normalized coordinates (x, y): 712 204
# Normalized coordinates (x, y): 712 204
# Normalized coordinates (x, y): 712 204
# Normalized coordinates (x, y): 710 204
# Normalized coordinates (x, y): 710 204
# Normalized coordinates (x, y): 710 204
# Normalized coordinates (x, y): 708 204
# Normalized coordinates (x, y): 706 206
# Normalized coordinates (x, y): 706 206
# Normalized coordinates (x, y): 704 208
# Normalized coordinates (x, y): 702 208
# Normalized coordinates (x, y): 700 209
# Normalized coordinates (x, y): 680 222
# Normalized coordinates (x, y): 678 224
# Normalized coordinates (x, y): 674 225
# Normalized coordinates (x, y): 672 227
# Normalized coordinates (x, y): 670 227
# Normalized coordinates (x, y): 670 228
# Normalized coordinates (x, y): 668 230
# Normalized coordinates (x, y): 666 230
# Normalized coordinates (x, y): 622 368
# Normalized coordinates (x, y): 620 368
# Normalized coordinates (x, y): 612 366
# Normalized coordinates (x, y): 608 363
# Normalized coordinates (x, y): 604 361
# Normalized coordinates (x, y): 600 358
# Normalized coordinates (x, y): 596 356
# Normalized coordinates (x, y): 592 355
# Normalized coordinates (x, y): 590 352
# Normalized coordinates (x, y): 588 350
# Normalized coordinates (x, y): 586 348
# Normalized coordinates (x, y): 582 348
# Normalized coordinates (x, y): 578 350
# Normalized coordinates (x, y): 576 350
# Normalized coordinates (x, y): 574 350
# Normalized coordinates (x, y): 574 348
# Normalized coordinates (x, y): 574 345
# Normalized coordinates (x, y): 576 342
# Normalized coordinates (x, y): 578 337
# Normalized coordinates (x, y): 580 334
# Normalized coordinates (x, y): 580 332
# Normalized coordinates (x, y): 580 331
# Normalized coordinates (x, y): 580 331
# Normalized coordinates (x, y): 578 332
# Normalized coordinates (x, y): 578 334
# Normalized coordinates (x, y): 576 337
# Normalized coordinates (x, y): 574 342
# Normalized coordinates (x, y): 572 348
# Normalized coordinates (x, y): 570 355
# Normalized coordinates (x, y): 570 360
# Normalized coordinates (x, y): 570 366
# Normalized coordinates (x, y): 570 371
# Normalized coordinates (x, y): 570 376
# Normalized coordinates (x, y): 570 382
# Normalized coordinates (x, y): 570 388
# Normalized coordinates (x, y): 572 396
# Normalized coordinates (x, y): 572 404
# Normalized coordinates (x, y): 574 414
# Normalized coordinates (x, y): 576 422
# Normalized coordinates (x, y): 578 430
# Normalized coordinates (x, y): 582 435
# Normalized coordinates (x, y): 606 465
# Normalized coordinates (x, y): 608 467
# Normalized coordinates (x, y): 610 465
# Normalized coordinates (x, y): 612 465
# Normalized coordinates (x, y): 614 462
# Normalized coordinates (x, y): 614 460
# Normalized coordinates (x, y): 614 456
# Normalized coordinates (x, y): 614 451
# Normalized coordinates (x, y): 614 446
# Normalized coordinates (x, y): 612 440
# Normalized coordinates (x, y): 612 433
# Normalized coordinates (x, y): 610 427
# Normalized coordinates (x, y): 610 420
# Normalized coordinates (x, y): 608 412
# Normalized coordinates (x, y): 606 404
# Normalized coordinates (x, y): 606 396
# Normalized coordinates (x, y): 604 388
# Normalized coordinates (x, y): 604 380
# Normalized coordinates (x, y): 604 372
# Normalized coordinates (x, y): 602 364
# Normalized coordinates (x, y): 602 356
# Normalized coordinates (x, y): 602 350
# Normalized coordinates (x, y): 604 344
# Normalized coordinates (x, y): 604 337
# Normalized coordinates (x, y): 604 334
# Normalized coordinates (x, y): 604 329
# Normalized coordinates (x, y): 604 328
# Normalized coordinates (x, y): 602 328
# Normalized coordinates (x, y): 602 328
# Normalized coordinates (x, y): 602 331
# Normalized coordinates (x, y): 600 334
# Normalized coordinates (x, y): 600 339
# Normalized coordinates (x, y): 598 344
# Normalized coordinates (x, y): 598 348
# Normalized coordinates (x, y): 598 355
# Normalized coordinates (x, y): 596 363
# Normalized coordinates (x, y): 598 369
# Normalized coordinates (x, y): 598 377
# Normalized coordinates (x, y): 598 384
# Normalized coordinates (x, y): 598 390
# Normalized coordinates (x, y): 600 396
# Normalized coordinates (x, y): 600 403
# Normalized coordinates (x, y): 602 409
# Normalized coordinates (x, y): 604 416
# Normalized coordinates (x, y): 604 422
# Normalized coordinates (x, y): 606 428
# Normalized coordinates (x, y): 608 433
# Normalized coordinates (x, y): 608 440
# Normalized coordinates (x, y): 610 443
# Normalized coordinates (x, y): 610 448
# Normalized coordinates (x, y): 612 451
# Normalized coordinates (x, y): 612 452
# Normalized coordinates (x, y): 614 454
# Normalized coordinates (x, y): 614 456
# Normalized coordinates (x, y): 614 456
# Normalized coordinates (x, y): 614 454
# Normalized coordinates (x, y): 612 454
# Normalized coordinates (x, y): 612 452
# Normalized coordinates (x, y): 610 449
# Normalized coordinates (x, y): 608 446
# Normalized coordinates (x, y): 606 443
# Normalized coordinates (x, y): 606 440
# Normalized coordinates (x, y): 604 436
# Normalized coordinates (x, y): 602 432
# Normalized coordinates (x, y): 600 427
# Normalized coordinates (x, y): 598 422
# Normalized coordinates (x, y): 598 417
# Normalized coordinates (x, y): 596 412
# Normalized coordinates (x, y): 596 406
# Normalized coordinates (x, y): 596 401
# Normalized coordinates (x, y): 596 398
# Normalized coordinates (x, y): 720 369
# Normalized coordinates (x, y): 714 371
# Normalized coordinates (x, y): 700 371
# Normalized coordinates (x, y): 690 372
# Normalized coordinates (x, y): 680 372
# Normalized coordinates (x, y): 670 374
# Normalized coordinates (x, y): 660 377
# Normalized coordinates (x, y): 652 379
# Normalized coordinates (x, y): 642 382
# Normalized coordinates (x, y): 636 387
# Normalized coordinates (x, y): 628 392
# Normalized coordinates (x, y): 620 395
# Normalized coordinates (x, y): 614 398
# Normalized coordinates (x, y): 610 401
# Normalized coordinates (x, y): 608 401
# Normalized coordinates (x, y): 610 398
# Normalized coordinates (x, y): 616 388
# Normalized coordinates (x, y): 626 377
# Normalized coordinates (x, y): 640 364
# Normalized coordinates (x, y): 658 352
# Normalized coordinates (x, y): 678 340
# Normalized coordinates (x, y): 700 329
# Normalized coordinates (x, y): 726 321
# Normalized coordinates (x, y): 752 316
# Normalized coordinates (x, y): 780 315
# Normalized coordinates (x, y): 810 316
# Normalized coordinates (x, y): 838 321
# Normalized coordinates (x, y): 866 331
# Normalized coordinates (x, y): 890 342
# Normalized coordinates (x, y): 914 356
# Normalized coordinates (x, y): 934 372
# Normalized coordinates (x, y): 952 390
# Normalized coordinates (x, y): 966 408
# Normalized coordinates (x, y): 974 553
# Normalized coordinates (x, y): 976 422
# Normalized coordinates (x, y): 978 550
# Normalized coordinates (x, y): 980 436
# Normalized coordinates (x, y): 978 545
# Normalized coordinates (x, y): 978 448
# Normalized coordinates (x, y): 970 545
# Normalized coordinates (x, y): 972 456
# Normalized coordinates (x, y): 964 462
# Normalized coordinates (x, y): 954 467
# Normalized coordinates (x, y): 942 467
# Normalized coordinates (x, y): 928 464
# Normalized coordinates (x, y): 910 457
# Normalized coordinates (x, y): 892 552
# Normalized coordinates (x, y): 892 448
# Normalized coordinates (x, y): 874 553
# Normalized coordinates (x, y): 872 438
# Normalized coordinates (x, y): 854 558
# Normalized coordinates (x, y): 852 427
# Normalized coordinates (x, y): 836 561
# Normalized coordinates (x, y): 832 414
# Normalized coordinates (x, y): 812 403
# Normalized coordinates (x, y): 796 390
# Normalized coordinates (x, y): 778 379
# Normalized coordinates (x, y): 764 369
# Normalized coordinates (x, y): 626 355
# Normalized coordinates (x, y): 752 360
# Normalized coordinates (x, y): 742 350
# Normalized coordinates (x, y): 734 344
# Normalized coordinates (x, y): 726 337
# Normalized coordinates (x, y): 642 369
# Normalized coordinates (x, y): 720 331
# Normalized coordinates (x, y): 644 372
# Normalized coordinates (x, y): 716 326
# Normalized coordinates (x, y): 646 374
# Normalized coordinates (x, y): 712 321
# Normalized coordinates (x, y): 708 316
# Normalized coordinates (x, y): 706 313
# Normalized coordinates (x, y): 704 310
# Normalized coordinates (x, y): 702 308
# Normalized coordinates (x, y): 652 382
# Normalized coordinates (x, y): 702 305
# Normalized coordinates (x, y): 702 304
# Normalized coordinates (x, y): 650 384
# Normalized coordinates (x, y): 704 302
# Normalized coordinates (x, y): 704 302
# Normalized coordinates (x, y): 706 302
# Normalized coordinates (x, y): 706 302
# Normalized coordinates (x, y): 708 302
# Normalized coordinates (x, y): 710 302
# Normalized coordinates (x, y): 710 302
# Normalized coordinates (x, y): 712 302
# Normalized coordinates (x, y): 800 225
# Normalized coordinates (x, y): 796 224
# Normalized coordinates (x, y): 792 222
# Normalized coordinates (x, y): 784 220
# Normalized coordinates (x, y): 776 219
# Normalized coordinates (x, y): 766 219
# Normalized coordinates (x, y): 754 219
# Normalized coordinates (x, y): 744 219
# Normalized coordinates (x, y): 732 219
# Normalized coordinates (x, y): 720 219
# Normalized coordinates (x, y): 708 220
# Normalized coordinates (x, y): 696 224
# Normalized coordinates (x, y): 684 225
# Normalized coordinates (x, y): 674 228
# Normalized coordinates (x, y): 664 232
# Normalized coordinates (x, y): 654 235
# Normalized coordinates (x, y): 646 240
# Normalized coordinates (x, y): 638 244
# Normalized coordinates (x, y): 630 249
# Normalized coordinates (x, y): 624 252
# Normalized coordinates (x, y): 618 257
# Normalized coordinates (x, y): 614 262
# Normalized coordinates (x, y): 608 267
# Normalized coordinates (x, y): 604 272
# Normalized coordinates (x, y): 600 276
# Normalized coordinates (x, y): 598 280
# Normalized coordinates (x, y): 594 283
# Normalized coordinates (x, y): 594 286
# Normalized coordinates (x, y): 592 286
# Normalized coordinates (x, y): 594 286
# Normalized coordinates (x, y): 594 284
# Normalized coordinates (x, y): 596 283
# Normalized coordinates (x, y): 598 281
# Normalized coordinates (x, y): 600 278
# Normalized coordinates (x, y): 604 275
# Normalized coordinates (x, y): 610 270
# Normalized coordinates (x, y): 616 265
# Normalized coordinates (x, y): 624 259
# Normalized coordinates (x, y): 632 252
# Normalized coordinates (x, y): 642 246
# Normalized coordinates (x, y): 652 240
# Normalized coordinates (x, y): 662 235
# Normalized coordinates (x, y): 676 228
# Normalized coordinates (x, y): 688 224
# Normalized coordinates (x, y): 702 220
# Normalized coordinates (x, y): 716 217
# Normalized coordinates (x, y): 728 214
# Normalized coordinates (x, y): 742 212
# Normalized coordinates (x, y): 756 212
# Normalized coordinates (x, y): 770 212
# Normalized coordinates (x, y): 784 214
# Normalized coordinates (x, y): 796 216
# Normalized coordinates (x, y): 808 219
# Normalized coordinates (x, y): 818 222
# Normalized coordinates (x, y): 826 227
# Normalized coordinates (x, y): 836 232
# Normalized coordinates (x, y): 846 238
# Normalized coordinates (x, y): 856 243
# Normalized coordinates (x, y): 866 248
# Normalized coordinates (x, y): 874 254
# Normalized coordinates (x, y): 880 259
# Normalized coordinates (x, y): 886 264
# Normalized coordinates (x, y): 888 267
# Normalized coordinates (x, y): 888 272
# Normalized coordinates (x, y): 886 275
# Normalized coordinates (x, y): 884 280
# Normalized coordinates (x, y): 882 283
# Normalized coordinates (x, y): 878 286
# Normalized coordinates (x, y): 870 289
# Normalized coordinates (x, y): 862 291
# Normalized coordinates (x, y): 854 292
# Normalized coordinates (x, y): 844 294
# Normalized coordinates (x, y): 836 294
# Normalized coordinates (x, y): 828 292
# Normalized coordinates (x, y): 820 291
# Normalized coordinates (x, y): 596 392
# Normalized coordinates (x, y): 810 289
# Normalized coordinates (x, y): 800 286
# Normalized coordinates (x, y): 790 284
# Normalized coordinates (x, y): 612 395
# Normalized coordinates (x, y): 780 283
# Normalized coordinates (x, y): 616 396
# Normalized coordinates (x, y): 770 280
# Normalized coordinates (x, y): 760 276
# Normalized coordinates (x, y): 752 273
# Normalized coordinates (x, y): 630 400
# Normalized coordinates (x, y): 744 272
# Normalized coordinates (x, y): 634 401
# Normalized coordinates (x, y): 736 268
# Normalized coordinates (x, y): 638 403
# Normalized coordinates (x, y): 728 265
# Normalized coordinates (x, y): 722 264
# Normalized coordinates (x, y): 644 404
# Normalized coordinates (x, y): 716 262
# Normalized coordinates (x, y): 710 260
# Normalized coordinates (x, y): 704 260
# Normalized coordinates (x, y): 700 260
# Normalized coordinates (x, y): 696 260
# Normalized coordinates (x, y): 694 260
# Normalized coordinates (x, y): 656 404
# Normalized coordinates (x, y): 692 262
# Normalized coordinates (x, y): 658 404
# Normalized coordinates (x, y): 690 262
# Normalized coordinates (x, y): 690 264
# Normalized coordinates (x, y): 658 403
# Normalized coordinates (x, y): 688 265
# Normalized coordinates (x, y): 688 267
# Normalized coordinates (x, y): 658 401
# Normalized coordinates (x, y): 688 268
# Normalized coordinates (x, y): 688 270
# Normalized coordinates (x, y): 658 400
# Normalized coordinates (x, y): 690 272
# Normalized coordinates (x, y): 690 275
# Normalized coordinates (x, y): 690 276
# Normalized coordinates (x, y): 656 396
# Normalized coordinates (x, y): 692 278
# Normalized coordinates (x, y): 692 280
# Normalized coordinates (x, y): 694 281
# Normalized coordinates (x, y): 656 395
# Normalized coordinates (x, y): 694 283
# Normalized coordinates (x, y): 696 283
# Normalized coordinates (x, y): 696 283
# Normalized coordinates (x, y): 698 283
# Normalized coordinates (x, y): 648 323
# Normalized coordinates (x, y): 648 323
# Normalized coordinates (x, y): 648 323
# Normalized coordinates (x, y): 650 321
# Normalized coordinates (x, y): 650 321
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 318
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 320
# Normalized coordinates (x, y): 650 321
# Normalized coordinates (x, y): 650 321
# Normalized coordinates (x, y): 650 321
# Normalized coordinates (x, y): 650 323
# Normalized coordinates (x, y): 648 323
# Normalized coordinates (x, y): 648 324
# Normalized coordinates (x, y): 648 326
# Normalized coordinates (x, y): 646 326
# Normalized coordinates (x, y): 646 328
# Normalized coordinates (x, y): 644 328
# Normalized coordinates (x, y): 644 329
# Normalized coordinates (x, y): 642 332
# Normalized coordinates (x, y): 640 334
# Normalized coordinates (x, y): 640 337
# Normalized coordinates (x, y): 638 340
# Normalized coordinates (x, y): 636 344
# Normalized coordinates (x, y): 634 347
# Normalized coordinates (x, y): 632 352
# Normalized coordinates (x, y): 630 355
# Normalized coordinates (x, y): 628 358
# Normalized coordinates (x, y): 628 363
# Normalized coordinates (x, y): 626 366
# Normalized coordinates (x, y): 626 369
# Normalized coordinates (x, y): 626 372
# Normalized coordinates (x, y): 626 376
# Normalized coordinates (x, y): 626 377
# Normalized coordinates (x, y): 624 380
# Normalized coordinates (x, y): 624 382
# Normalized coordinates (x, y): 624 384
# Normalized coordinates (x, y): 624 385
# Normalized coordinates (x, y): 624 387
# Normalized coordinates (x, y): 624 387
# Normalized coordinates (x, y): 624 388
# Normalized coordinates (x, y): 624 390
# Normalized coordinates (x, y): 624 392
# Normalized coordinates (x, y): 624 393
# Normalized coordinates (x, y): 624 395
# Normalized coordinates (x, y): 622 398
# Normalized coordinates (x, y): 622 401
# Normalized coordinates (x, y): 622 403
# Normalized coordinates (x, y): 620 408
# Normalized coordinates (x, y): 620 411
# Normalized coordinates (x, y): 620 416
# Normalized coordinates (x, y): 618 420
# Normalized coordinates (x, y): 618 425
# Normalized coordinates (x, y): 618 430
# Normalized coordinates (x, y): 620 433
# Normalized coordinates (x, y): 620 424
# Normalized coordinates (x, y): 620 422
# Normalized coordinates (x, y): 620 420
# Normalized coordinates (x, y): 642 408
# Normalized coordinates (x, y): 644 408
# Normalized coordinates (x, y): 652 409
# Normalized coordinates (x, y): 660 411
# Normalized coordinates (x, y): 668 412
# Normalized coordinates (x, y): 676 416
# Normalized coordinates (x, y): 682 417
# Normalized coordinates (x, y): 688 420
# Normalized coordinates (x, y): 694 422
# Normalized coordinates (x, y): 698 425
# Normalized coordinates (x, y): 700 428
# Normalized coordinates (x, y): 704 432
# Normalized coordinates (x, y): 708 435
# Normalized coordinates (x, y): 710 440
# Normalized coordinates (x, y): 712 444
# Normalized coordinates (x, y): 712 451
# Normalized coordinates (x, y): 712 456
# Normalized coordinates (x, y): 714 462
# Normalized coordinates (x, y): 714 468
# Normalized coordinates (x, y): 716 475
# Normalized coordinates (x, y): 718 483
# Normalized coordinates (x, y): 722 489
# Normalized coordinates (x, y): 724 496
# Normalized coordinates (x, y): 726 502
# Normalized coordinates (x, y): 728 508
# Normalized coordinates (x, y): 730 513
# Normalized coordinates (x, y): 732 518
# Normalized coordinates (x, y): 732 523
# Normalized coordinates (x, y): 734 526
# Normalized coordinates (x, y): 734 529
# Normalized coordinates (x, y): 734 531
# Normalized coordinates (x, y): 732 532
# Normalized coordinates (x, y): 732 534
# Normalized coordinates (x, y): 730 534
# Normalized coordinates (x, y): 730 536
# Normalized coordinates (x, y): 728 536
# Normalized coordinates (x, y): 728 536
# Normalized coordinates (x, y): 726 536
# Normalized coordinates (x, y): 724 536
# Normalized coordinates (x, y): 724 536
# Normalized coordinates (x, y): 722 536
# Normalized coordinates (x, y): 720 536
# Normalized coordinates (x, y): 720 536
# Normalized coordinates (x, y): 720 536
# Normalized coordinates (x, y): 718 536
# Normalized coordinates (x, y): 718 536
# Normalized coordinates (x, y): 718 534
# Normalized coordinates (x, y): 718 532
# Normalized coordinates (x, y): 716 531
# Normalized coordinates (x, y): 714 529
# Normalized coordinates (x, y): 710 528
# Normalized coordinates (x, y): 708 524
# Normalized coordinates (x, y): 704 523
# Normalized coordinates (x, y): 702 520
# Normalized coordinates (x, y): 698 516
# Normalized coordinates (x, y): 696 513
# Normalized coordinates (x, y): 694 512
# Normalized coordinates (x, y): 692 508
# Normalized coordinates (x, y): 690 505
# Normalized coordinates (x, y): 688 502
# Normalized coordinates (x, y): 686 500
# Normalized coordinates (x, y): 684 497
# Normalized coordinates (x, y): 682 496
# Normalized coordinates (x, y): 682 494
# Normalized coordinates (x, y): 680 492
# Normalized coordinates (x, y): 680 491
# Normalized coordinates (x, y): 678 489
# Normalized coordinates (x, y): 678 489
# Normalized coordinates (x, y): 680 489
# Normalized coordinates (x, y): 680 491
# Normalized coordinates (x, y): 680 491
# Normalized coordinates (x, y): 680 492
# Normalized coordinates (x, y): 682 494
# Normalized coordinates (x, y): 684 496
# Normalized coordinates (x, y): 684 499
# Normalized coordinates (x, y): 686 502
# Normalized coordinates (x, y): 688 505
# Normalized coordinates (x, y): 692 508
# Normalized coordinates (x, y): 694 513
# Normalized coordinates (x, y): 696 516
# Normalized coordinates (x, y): 700 520
# Normalized coordinates (x, y): 702 524
# Normalized coordinates (x, y): 704 528
# Normalized coordinates (x, y): 706 531
# Normalized coordinates (x, y): 708 534
# Normalized coordinates (x, y): 710 536
# Normalized coordinates (x, y): 710 539
# Normalized coordinates (x, y): 712 540
# Normalized coordinates (x, y): 712 542
# Normalized coordinates (x, y): 714 545
# Normalized coordinates (x, y): 714 547
# Normalized coordinates (x, y): 716 550
# Normalized coordinates (x, y): 716 552
# Normalized coordinates (x, y): 718 553
# Normalized coordinates (x, y): 718 553
# Normalized coordinates (x, y): 700 553
# Normalized coordinates (x, y): 698 553
# Normalized coordinates (x, y): 698 553
# Normalized coordinates (x, y): 694 552
# Normalized coordinates (x, y): 692 550
# Normalized coordinates (x, y): 690 548
# Normalized coordinates (x, y): 686 547
# Normalized coordinates (x, y): 684 544
# Normalized coordinates (x, y): 680 544
# Normalized coordinates (x, y): 662 537
# Normalized coordinates (x, y): 664 537
# Normalized coordinates (x, y): 666 540
# Normalized coordinates (x, y): 668 542
# Normalized coordinates (x, y): 668 544
# Normalized coordinates (x, y): 676 552
# Normalized coordinates (x, y): 678 553
# Normalized coordinates (x, y): 622 452
# Normalized coordinates (x, y): 622 446
# Normalized coordinates (x, y): 622 441
# Normalized coordinates (x, y): 624 436
# Normalized coordinates (x, y): 624 432
# Normalized coordinates (x, y): 624 427
# Normalized coordinates (x, y): 624 424
# Normalized coordinates (x, y): 624 420
# Normalized coordinates (x, y): 624 417
# Normalized coordinates (x, y): 626 414
# Normalized coordinates (x, y): 626 412
# Normalized coordinates (x, y): 626 409
# Normalized coordinates (x, y): 628 408
# Normalized coordinates (x, y): 628 406
# Normalized coordinates (x, y): 628 404
# Normalized coordinates (x, y): 628 403
# Normalized coordinates (x, y): 630 403
# Normalized coordinates (x, y): 630 401
# Normalized coordinates (x, y): 630 400
# Normalized coordinates (x, y): 630 398
# Normalized coordinates (x, y): 632 396
# Normalized coordinates (x, y): 632 396
# Normalized coordinates (x, y): 632 395
# Normalized coordinates (x, y): 632 393
# Normalized coordinates (x, y): 632 392
# Normalized coordinates (x, y): 632 390
# Normalized coordinates (x, y): 632 390
# Normalized coordinates (x, y): 632 388
# Normalized coordinates (x, y): 632 387
# Normalized coordinates (x, y): 630 387
# Normalized coordinates (x, y): 630 387
# Normalized coordinates (x, y): 628 387
# Normalized coordinates (x, y): 628 387
# Normalized coordinates (x, y): 626 390
# Normalized coordinates (x, y): 624 392
# Normalized coordinates (x, y): 608 422
# Normalized coordinates (x, y): 608 427
# Normalized coordinates (x, y): 606 435
# Normalized coordinates (x, y): 606 444
# Normalized coordinates (x, y): 606 452
# Normalized coordinates (x, y): 606 462
# Normalized coordinates (x, y): 608 470
# Normalized coordinates (x, y): 610 480
# Normalized coordinates (x, y): 612 484
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/cyclone/anaconda3/envs/test/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
